# %%
import pyodbc 
import pyodbc
conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=KASMO\MSSQLSERVER1;'
    'DATABASE=bikestores;'
    'UID=sa;'
    'PWD=Rakshitha#23'
)

# %%
import pandas as pd
query="select * from sales.customers"
df=pd.read_sql(query,conn)
df
# Out:
# C:\Users\Rakshita\AppData\Local\Temp\ipykernel_23004\2207468477.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,conn)
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks            None
# 1               2       Kasha      Todd            None
# 2               3      Tameka    Fisher            None
# 3               4       Daryl    Spence            None
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 5775         5776      Jamaal  Morrison            None
# 5776         5777      Cassie     Cline            None
# 5777         5778      Lezlie      Lamb            None
# 5778         5779      Ivette     Estes            None
# ...

# %%
df.loc[df['customer_id']==2,['first_name','last_name']]=['sathwick','reddy']
df.loc[df['customer_id']==4,['first_name','last_name']]=['Rakshitha','Reddy']
df
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks            None
# 1               2    sathwick     reddy            None
# 2               3      Tameka    Fisher            None
# 3               4   Rakshitha     Reddy            None
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 5775         5776      Jamaal  Morrison            None
# 5776         5777      Cassie     Cline            None
# 5777         5778      Lezlie      Lamb            None
# 5778         5779      Ivette     Estes            None
# 5779         5780       Ester   Acevedo            None
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
from datetime import datetime
df['start_date']=datetime.today().strftime('%y-%m-%d')
df['end_date']='None'

# %%
df
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks            None
# 1               2    sathwick     reddy            None
# 2               3      Tameka    Fisher            None
# 3               4   Rakshitha     Reddy            None
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 5775         5776      Jamaal  Morrison            None
# 5776         5777      Cassie     Cline            None
# 5777         5778      Lezlie      Lamb            None
# 5778         5779      Ivette     Estes            None
# 5779         5780       Ester   Acevedo            None
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
updates_customer={
    'customer_id':3,
    'first_name':'Rakshi',
    'last_name':'Reddy'
    }

# %%
df.loc[(df['customer_id']==updates_customer['customer_id'])&(df['end_date'].isnull()),'end_date']=datetime.today().strftime('%y-%m-%d')

# %%
new=df.loc[df['customer_id']==updates_customer['customer_id']].copy()
new
# Out:
#    customer_id first_name last_name phone                  email  \
# 2            3     Tameka    Fisher  None  tameka.fisher@aol.com
#
#                   street           city state zip_code start_date end_date
# 2  769C Honey Creek St.   Redondo Beach    CA    90278   25-06-25     None

# %%
new['first_name']=updates_customer['first_name']
new['last_name']=updates_customer['last_name']
new['start_time']=datetime.today().strftime('%y-%m-%d')
new['end_date']='None'
new
# Out:
#    customer_id first_name last_name phone                  email  \
# 2            3     Rakshi     Reddy  None  tameka.fisher@aol.com
#
#                   street           city state zip_code start_date end_date  \
# 2  769C Honey Creek St.   Redondo Beach    CA    90278   25-06-25     None
#
#   start_time
# 2   25-06-25

# %%
df=pd.concat([df,new],ignore_index=True)

# %%
df['previous_name']=df['first_name']
df
df.loc[df['customer_id'] == 2, 'previous_name'] = df.loc[df['customer_id'] == 2, 'first_name']

df.loc[df['customer_id']==2,'first_name']="Rashi"
df
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks            None
# 1               2       Rashi     reddy            None
# 2               3      Tameka    Fisher            None
# 3               4   Rakshitha     Reddy            None
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 5777         5778      Lezlie      Lamb            None
# 5778         5779      Ivette     Estes            None
# 5779         5780       Ester   Acevedo            None
# 5780            3      Rakshi     Reddy            None
# 5781            3      Rakshi     Reddy            None
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
df
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks            None
# 1               2    sathwick     reddy            None
# 2               3      Tameka    Fisher            None
# 3               4   Rakshitha     Reddy            None
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 5778         5779      Ivette     Estes            None
# 5779         5780       Ester   Acevedo            None
# 5780            3      Rakshi     Reddy            None
# 5781            3      Rakshi     Reddy            None
# 5782            3      Rakshi     Reddy            None
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
col=['customer_id','first_name','last_name','phone','city','state','zip_code']
history_table=pd.DataFrame(columns=col)
history_table
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, last_name, phone, city, state, zip_code]
# Index: []

# %%
update_data={
    'customer_id':2,
    'first_name':'Laxmi',
    'last_name':'Srinivas'
}
new_record=df.loc[df['customer_id']==update_data['customer_id']].copy()
new_record
# Out:
#    customer_id first_name last_name phone                 email  \
# 1            2      Rashi     reddy  None  kasha.todd@yahoo.com
#
#              street      city state zip_code start_date end_date start_time  \
# 1  910 Vine Street   Campbell    CA    95008   25-06-25     None        NaN
#
#   previous_name
# 1       Bhavana

# %%
df.loc[df['customer_id']==update_data['customer_id'],'first_name']=update_data['first_name']
df.loc[df['customer_id']==update_data['customer_id'],'last_name']=update_data['last_name']
history_table=pd.concat([history_table,new_record],axis=0)
history_table
# Out:
#   customer_id first_name last_name phone      city state zip_code  \
# 1           2      Rashi     reddy  None  Campbell    CA    95008
#
#                   email            street start_date end_date start_time  \
# 1  kasha.todd@yahoo.com  910 Vine Street    25-06-25     None        NaN
#
#   previous_name
# 1       Bhavana

# %%
df
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks            None
# 1               2       Laxmi  Srinivas            None
# 2               3      Tameka    Fisher            None
# 3               4   Rakshitha     Reddy            None
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 5777         5778      Lezlie      Lamb            None
# 5778         5779      Ivette     Estes            None
# 5779         5780       Ester   Acevedo            None
# 5780            3      Rakshi     Reddy            None
# 5781            3      Rakshi     Reddy            None
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...
